# %%
cd drive/MyDrive/kobert-wellness-chatbot/
# Out:
# /content/drive/MyDrive/kobert-wellness-chatbot

# %%
# !pip install -r requirements.txt

# %%
# !python train.py
# Out:
# tokenizer_config.json: 100% 432/432 [00:00<00:00, 2.22MB/s]
# spiece.model: 100% 371k/371k [00:00<00:00, 8.64MB/s]
# special_tokens_map.json: 100% 244/244 [00:00<00:00, 1.67MB/s]
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'XLNetTokenizer'.
# The class this function is called from is 'KoBERTTokenizer'.
# config.json: 100% 535/535 [00:00<00:00, 3.29MB/s]
# pytorch_model.bin: 100% 369M/369M [00:02<00:00, 162MB/s]
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'XLNetTokenizer'.
# The class this function is called from is 'KoBERTTokenizer'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'XLNetTokenizer'.
# The class this function is called from is 'KoBERTTokenizer'.
# /usr/local/lib/python3.10/dist-packages/transformers/optimization.py:588: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# Train(0): 100% 607/607 [03:33<00:00,  2.84it/s, Loss: 3.559 (3.550)]
# Train(1): 100% 607/607 [03:38<00:00,  2.77it/s, Loss: 3.337 (3.229)]
# Train(2): 100% 607/607 [03:42<00:00,  2.73it/s, Loss: 2.856 (2.798)]
# Train(3): 100% 607/607 [04:38<00:00,  2.18it/s, Loss: 3.067 (2.393)]
# Train(4): 100% 607/607 [05:16<00:00,  1.92it/s, Loss: 1.360 (2.041)]
# Train(5): 100% 607/607 [03:55<00:00,  2.58it/s, Loss: 2.106 (1.757)]
# Train(6): 100% 607/607 [04:01<00:00,  2.52it/s, Loss: 1.388 (1.506)]
# Train(7): 100% 607/607 [03:47<00:00,  2.67it/s, Loss: 1.725 (1.287)]
# Train(8): 100% 607/607 [03:53<00:00,  2.59it/s, Loss: 1.731 (1.092)]
# Train(9): 100% 607/607 [04:05<00:00,  2.47it/s, Loss: 0.154 (0.929)]

# %%
# https://newyearchive.tistory.com/2

# %%
# !python test.py
# Out:
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'XLNetTokenizer'.
# The class this function is called from is 'KoBERTTokenizer'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'XLNetTokenizer'.
# The class this function is called from is 'KoBERTTokenizer'.
#
# Question: 시험을 볼 때마다 성적이 낮아져. 성적이 오르지 않아서 슬퍼.
# index: 28, softmax_value: 0.6723566055297852
# --------------------------------------------------
#
# Question: 주말에 가족들과 함께 영화를 봤는데 재밌는 시간이었어.
# index: 32, softmax_value: 0.3134986162185669
# --------------------------------------------------
#
# Question: 내가 어제 수학 공식을 정리해 놓은 책을 훔쳐 가서 몹시 화가 나.
# index: 22, softmax_value: 0.699234664440155
# --------------------------------------------------
#
# Question: 음악 시간에 노래를 해야 하는데 노래를 못해서 하기가 두려워.
# index: 3, softmax_value: 0.5803194642066956
# --------------------------------------------------
#
# Question: 몸이 안 좋아 병원에 입원했는데 병원 사람들이 모두들 착하고 좋은 분위기인 거 같아서 편안해.
# index: 39, softmax_value: 0.6004320979118347
# --------------------------------------------------
#
# Question: 오늘 집에 오니 내가 그렇게 바라던 강아지가 있더라고! 너무 행복했어!
# index: 32, softmax_value: 0.2293965071439743
# --------------------------------------------------
#
# Question: 남자친구 집에서 데이트하는데 어머님이 갑작스럽게 방문하셔서 당황스러워.
# index: 8, softmax_value: 0.0957682728767395
# --------------------------------------------------
#
# Question: 매일 밤 잠 드는 게 어려워. 너무나 불안해.
# index: 2, softmax_value: 0.9340920448303223
# --------------------------------------------------
#
# Question: 출장이 잦은데 잠자리가 바뀌면 잠이 안 와서 스트레스야.
# index: 14, softmax_value: 0.8627252578735352
# --------------------------------------------------
#
# Question: 오늘 신체나이 검사를 했는데 나이보다 열 살이나 어리게 나와서 정말 신나!
# index: 32, softmax_value: 0.4375288188457489
# --------------------------------------------------
#
# Question: 많은 사람의 대인관계에서 적응이 어려운 성격이라 외로운 느낌이 들어.
# index: 5, softmax_value: 0.3500247597694397
# --------------------------------------------------
#
# Question: 친구한테 너무 서운하고 속상해.
# index: 6, softmax_value: 0.4075264036655426
# --------------------------------------------------
#
# Question: 내가 이렇게 아픈데 아무도 나에게 관심이 없어. 자식들마저 자기들 살기 바빠. 너무 화가 나!
# index: 22, softmax_value: 0.6988383531570435
# --------------------------------------------------
#
# Question: 왕년에는 내가 정말 힘이 좋기로 유명했는데 오늘 회사에서 여직원과 팔씨름을 했는데 졌어.
# index: 34, softmax_value: 0.2376440018415451
# --------------------------------------------------
#
# Question: 결혼하고 나서 친구들과 멀어진 건지 혼란스러워.
# index: 39, softmax_value: 0.12433236092329025
# --------------------------------------------------
#
# Question: 코로나 때문에 전 산업 경기가 안 좋아. 우리 회사 구조조정이 예견되어 있어 노심초사야.
# index: 1, softmax_value: 0.476145476102829
# --------------------------------------------------
#
# Question: 종료
# 료
