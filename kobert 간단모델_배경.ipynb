# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import torch
ctx = "cuda" if torch.cuda.is_available() else "cpu"
device = torch.device(ctx)
print(device)
# Out:
# cuda

# %%
cd drive/MyDrive/final_project
# Out:
# /content/drive/MyDrive/final_project

# %%
# !pip install -r requirements.txt

# %%
# !python background_train.py
# Out:
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'XLNetTokenizer'.
# The class this function is called from is 'KoBERTTokenizer'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'XLNetTokenizer'.
# The class this function is called from is 'KoBERTTokenizer'.
# /usr/local/lib/python3.10/dist-packages/transformers/optimization.py:588: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# Train(0): 100% 517/517 [02:52<00:00,  3.00it/s, Loss: 2.623 (3.375)]
# Train(1): 100% 517/517 [02:54<00:00,  2.96it/s, Loss: 3.207 (2.830)]
# Train(2): 100% 517/517 [02:54<00:00,  2.96it/s, Loss: 1.547 (2.287)]
# Train(3): 100% 517/517 [02:55<00:00,  2.95it/s, Loss: 2.699 (1.869)]
# Train(4): 100% 517/517 [02:55<00:00,  2.95it/s, Loss: 0.743 (1.554)]
# Train(5): 100% 517/517 [02:56<00:00,  2.93it/s, Loss: 1.074 (1.297)]
# Train(6): 100% 517/517 [02:56<00:00,  2.93it/s, Loss: 1.922 (1.073)]
# Train(7): 100% 517/517 [02:54<00:00,  2.96it/s, Loss: 0.137 (0.911)]
# Train(8): 100% 517/517 [02:55<00:00,  2.94it/s, Loss: 1.263 (0.763)]
# Train(9): 100% 517/517 [02:55<00:00,  2.95it/s, Loss: 0.438 (0.653)]

# %%
# https://newyearchive.tistory.com/2

# %%
# !python background_test.py
# Out:
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'XLNetTokenizer'.
# The class this function is called from is 'KoBERTTokenizer'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'XLNetTokenizer'.
# The class this function is called from is 'KoBERTTokenizer'.
#
# Question: 거짓말 한 친구가 내가 그랬다고 헛소문을 내고 다녀서 너무 당황스러워.
# index: 31, softmax_value: 0.46213918924331665
# --------------------------------------------------
#
# Question: 요즘 내 의견은 다 묵살하는 팀장님 때문에 화가 나는데 그 팀장님께 꼭! 반드시! 인정을 받을 거야.
# index: 27, softmax_value: 0.857019305229187
# --------------------------------------------------
#
# Question: 오늘 친구와 말싸움 하다가 그만 친구를 때렸어. 내가 왜 그랬는지 당황스러워.
# index: 31, softmax_value: 0.4192991554737091
# --------------------------------------------------
#
# Question: 전세금을 돌려받아서 다행이야.
# index: 3, softmax_value: 0.7168830037117004
# --------------------------------------------------
#
# Question: 당뇨 관리를 잘한다고 했는데 이번에 공복 수치가 너무 높게 나와서 실망이야.
# index: 1, softmax_value: 0.80775386095047
# --------------------------------------------------
#
# Question: 뭐든 다 잘하는 오빠한테 너무 열등감이 들어.
# index: 20, softmax_value: 0.7564243078231812
# --------------------------------------------------
#
# Question: 돈이 없어서 놀러 다니지를 못하니 외로워.
# index: 9, softmax_value: 0.28256890177726746
# --------------------------------------------------
#
# Question: 오늘도 영업 실적을 위해 많은 사람을 만나고 비위를 맞추어 주었어. 참 힘드네.
# index: 27, softmax_value: 0.9137684106826782
# --------------------------------------------------
#
# Question: 종료
